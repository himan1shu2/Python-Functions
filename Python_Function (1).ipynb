# %% [markdown]
# 1.What is the difference between a function and a method in Python?
#    - Function -
#         - Definition: A function is a block of reusable code that performs a specific task.
#         - Defined using: The def keyword at the top level or inside other functions.
#         - Called using: Just the function name with parentheses, function_name().
#
#               def sum(a,b):
#                   return a+b
#               sum(4,5)
#
#    - Method -
#        - Definition: A method is a function that is associated with an object (usually an instance of a class).
#        - Defined inside a class using def.
#        - Called using: The object (instance) with dot notation, e.g., object.method().
#
#               class Boy:
#                    def eat_apple(self):
#                       print("Boy is eating an apple")
#               b = Boy()
#               b.eat_apple()
#
# 2.Explain the concept of function arguments and parameters in Python.
#   - Parameters - are the names used when defining a function.
#   - Arguments - are the values passed when calling a function.
#         def greet(name):  # 'name' is a parameter
#             print("Hello", name)
#
#         # Function call
#         greet("Ankit")  # "Ankit" is an argument
#
# 3.What are the different ways to define and call a function in Python?
#    - Different Ways to Define and Call a Function in Python (Short Version)
#
# |   | Type                          | Define Example                          | Call Example             |
# |----|-------------------------------|------------------------------------------|---------------------------|
# | 1️⃣ | **Normal Function**           | `def greet(name):`                      | `greet("Ankit")`          |
# | 2️⃣ | **Default Argument**          | `def greet(name="Guest"):`              | `greet()` / `greet("Ali")`|
# | 3️⃣ | **Keyword Argument**          | `def intro(name, age):`                 | `intro(age=20, name="A")` |
# | 4️⃣ | **Variable Positional** `*args` | `def total(*nums):`                     | `total(1, 2, 3)`          |
# | 5️⃣ | **Variable Keyword** `**kwargs` | `def info(**data):`                     | `info(name="Ali")`        |
# | 6️⃣ | **Lambda (short function)**   | `add = lambda x, y: x + y`              | `add(3, 4)`               |
# | 7️⃣ | **Nested Function**           | `def outer(): def inner(): ...`         | `outer()`                 |
# | 8️⃣ | **Recursive Function**        | `def fact(n): return n*fact(n-1)`       | `fact(5)`                 |
#
# 4.What is the purpose of the return statement in a Python function?
#   - What does return do?
#      - The return statement sends a result back from a function to where the function was called.
#      - It ends the function execution and outputs a value.
#      - Without return, a function returns None by default.
#   - Why use return?
#     - To get output from a function and use it later.
#     - To pass calculated values back to the caller.
#     - To stop the function once a result is ready.
#
#           def add(a, b):
#               return a + b  # Returns the sum
#           result = add(3, 5)
#           print(result)  # Output: 8
#
#            ##without return
#           def add(a, b):
#               print(a + b)  # Just prints, no return
#           result = add(3, 5)
#           print(result)  # Output: None
#
# 5.What are iterators in Python and how do they differ from iterables?
#    -  Iterable -
#         - An iterable is any Python object you can loop over (e.g., using a for loop).
# Examples: lists, tuples, strings, dictionaries, sets.
#
#       - Characteristics:
#
#           - Has an __iter__() method that returns an iterator.
#
#           - Can be passed to iter() function to get an iterator.
#
#                 my_list = [1, 2, 3]  # This is an iterable
#                 for item in my_list:
#                     print(item)
#
# - Iterator -
#     - An iterator is an object that produces the next value when you ask for it, one at a time. It keeps track of the current position in the sequence.
#     - Characteristics:
#         - Has a __next__() method that returns the next item.
#         - Raises StopIteration when no more items are left.
#         - Has an __iter__() method that returns itself.
#
#
#            my_list = [1, 2, 3]
#            it = iter(my_list)  # 'it' is an iterator
#
#           print(next(it))  # 1
#           print(next(it))  # 2
#           print(next(it))  # 3
#           # next(it) now would raise StopIteration
# 6.Explain the concept of generators in Python and how they are defined?
#   - Generator -
#       - A generator is a special kind of iterator that generates values on the fly, one at a time, only when requested.
#       - It does not store all values in memory; it produces them lazily, which makes it memory efficient, especially for large data.
#   - How are Generators Defined?
#       - There are two main ways to create generators in Python -
#          - A. Generator Function (using yield)
#
#                def count_up_to(n):
#                    count = 1
#                    while count <= n:
#                          yield count  # produce current count and pause
#                          count += 1
#
#                #Using the generator
#                counter = count_up_to(5)
#                print(next(counter))  # 1
#                print(next(counter))  # 2
#
#            - B. Generator Expression (like list comprehension but with parentheses)
#
#                  squares = (x*x for x in range(5))
#                  print(next(squares))  # 0
#                  print(next(squares))  # 1
#
#
#   - Why  Use Generators?
#      - Memory efficient: No need to store the entire sequence in memory.
#      - Lazy evaluation: Values are produced only when needed.
#      - Useful for working with large datasets or infinite sequences.
#
# 7.What are the advantages of using generators over regular functions?
#
#   - Summary Table: Advantages of Generators
#
# | Advantage               | Explanation                                           |
# |-------------------------|-------------------------------------------------------|
# | Memory efficient        | Doesn’t store entire data in memory                  |
# | Lazy evaluation         | Computes values only when needed                     |
# | Fast startup            | No delay from precomputing large data                |
# | Infinite sequence safe  | Can represent endless data without crashing          |
# | Clean code              | Uses yield for simple iteration logic
#
#
#
# 8.What is a lambda function in Python and when is it typically used?
#   - A lambda function in Python is a small, anonymous (nameless) function defined using the lambda keyword.
#   - It's used when you need a short function for a short time.
#   - It can have any number of arguments, but only one expression (no multiple lines)
#             syntax:   lambda arguments: expression
#
#             example:
#
#             def add(x, y):   # normal function
#                          return x + y
#
#             add = lambda x, y: x + y  # Same using lambda
#             print(add(2, 3))  # Output: 5
#
#         ### 🔸 Common Uses of `lambda` Functions in Python
#
# | No. | Use Case                  | Example Code Snippet                                     | Purpose                          |
# |-----|---------------------------|-----------------------------------------------------------|----------------------------------|
# | 1️ | With map()            | map(lambda x: x*2, [1, 2, 3])`                           | Transform each item in a list    |
# | 2️ | With filter()          | filter(lambda x: x % 2 == 0, [1, 2, 3, 4])`              | Filter even numbers              |
# | 3️ | With sorted()           | sorted(names, key=lambda x: x.lower())`                 | Custom sorting logic             |
# | 4️ | Quick math function       | lambda x, y: x + y`                                      | One-line addition                |
# | 5️ | With reduce() (from functools) | reduce(lambda x, y: x + y, [1, 2, 3])`         | Reduce a list to a single value  |
# | 6️ | Inside GUI/event code     | button.command = lambda: do_something()`                | Short callback functions         |
#
#
#
# 9.Explain the purpose and usage of the map() function in Python.
#   - The map() -
#     - function in Python is used to apply a function to every item in an iterable (like a list, tuple, etc.) and return a new iterator with the results.
#   - Purpose -
#       -  To avoid writing loops for applying the same function to many values.
#       - Makes code shorter, cleaner, and faster (especially with lambda functions).
#
#              syntax - map(function, iterable)
#              ## function: A function that processes each item.
#              ## iterable: A list, tuple, etc.
#   - Returns what?
#        - map() returns a map object (an iterator).
#        - You need to use list(), tuple(), or loop to see the results.
#
#   - Usage Example
#      - 1: Using map() with a function
#
#            def square(x):
#                return x * x
#
#            numbers = [1, 2, 3, 4]
#            result = map(square, numbers)
#
#            print(list(result))  # Output: [1, 4, 9, 16]
#
#       - 2: Using map() with lambda
#
#               numbers = [1, 2, 3, 4]
#               result = map(lambda x: x + 10, numbers)
#
#               print(list(result))  # Output: [11, 12, 13, 14]
#
# 10.What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#   - Similarity -
#      - Take a function as the first argument
#      - Work on iterables (like lists)
#      - Return results based on how the function is applied
#
#   - map() – Transforms each item
#     - Purpose: Apply a function to every item in an iterable.
#     - Returns: A new iterator with transformed items.
#
# ```
# nums = [1, 2, 3]
# result = map(lambda x: x * 2, nums)
# print(list(result))  # [2, 4, 6]
#  ```
#   - filter() – Filters items
#        - Purpose: Keep items that return True from the function.
#        - Returns: A new iterator with filtered items.
#
# ```
# nums = [1, 2, 3, 4]
# result = filter(lambda x: x % 2 == 0, nums)
# print(list(result))  # [2, 4]
# ```
#
#    - reduce() – Reduces all items to one
#         - Purpose: Repeatedly apply a function to items to reduce them to a single value.
#         -  Returns: A single final value.
#         - `Must import from functools.`
#
# ```
# from functools import reduce
#
# nums = [1, 2, 3, 4]
# result = reduce(lambda x, y: x + y, nums)
# print(result)  # 10
# ```
#
# 11.Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given list:[47,11,42,13];
#   - Solution
# ![image.png](data:image/png;base64,...)

# %%
#1 . Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.
def sum_of_even_numbers(numbers):
    total = 0
    for num in numbers:
        if num % 2 == 0:
            total += num
    return total

my_list = [10, 3, 5, 6, 8]
print(sum_of_even_numbers(my_list))
# Out:
# 24

# %%
#2. Create a Python function that accepts a string and returns the reverse of that string.
def reverse_string(text):
    return text[::-1]
n = input("enter string: ")
print(reverse_string(n))
# Out:
# enter string: pwskills
# sllikswp

# %%
#3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.
def square_numbers(numbers):
    return list(map(lambda x: x ** 2, numbers))
square_numbers([1,2,3,4])
# Out:
# [1, 4, 9, 16]

# %%
#4. Write a Python function that checks if a given number is prime or not from 1 to 200.
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, n):
        if n % i == 0:
            return False
    return True

print(is_prime(17))
print(is_prime(20))
# Out:
# True
# False

# %%
#5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.
class FibonacciIterator:
    def __init__(self, n):
        self.n = n
        self.a, self.b = 0, 1
        self.count = 0

# %%
#6. Write a generator function in Python that yields the powers of 2 up to a given exponent.
def powers_of_2(n):
    i = 0
    while i <= n:
        yield 2 ** i
        i += 1
for val in powers_of_2(4):
    print(val, end=' ')
# Out:
# 1 2 4 8 16

# %%
#7. Implement a generator function that reads a file line by line and yields each line as a string.
def read_file_line_by_line(filename):
    with open(filename, 'r') as file:
        for line in file:
            yield line.rstrip('\n')
for line in read_file_line_by_line('example.txt'):
    print(line)

# %%
#8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
my_list = [(1, 3), (2, 1), (4, 2), (3, 5)]
sorted_list = sorted(my_list, key=lambda x: x[1])
print(sorted_list)
# Out:
# [(2, 1), (4, 2), (1, 3), (3, 5)]

# %%
#9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.
def celsius_to_fahrenheit(c):
    return (c * 9/5) + 32

celsius_temps = [0, 20, 37, 100]
fahrenheit_temps = list(map(celsius_to_fahrenheit, celsius_temps))

print(fahrenheit_temps)
# Out:
# [32.0, 68.0, 98.6, 212.0]

# %%
#10. Create a Python program that uses `filter()` to remove all the vowels from a given string.
def is_not_vowel(char):
    return char.lower() not in 'aeiou'

input_string = "Hello, how are you?"
result = ''.join(filter(is_not_vowel, input_string))

print(result)
# Out:
# Hll, hw r y?

# %%
#11.Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:

#Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and theproduct of the price per item and the quantity. The product should be increased by 10,- € if the value of theorder is smaller than 100,00 €.

#Write a Python program using lambda and map.
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

result = []

for order in orders:
    order_num = order[0]
    total = order[2] * order[3]  # quantity * price
    if total < 100:
        total += 10  # add 10 € if total is less than 100
    result.append((order_num, total))

print(result)

result = list(
    map(
        lambda order: (
            order[0],
            order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0)
        ),
        orders
    )
)

print(result)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]

# %%
from google.colab import files

uploaded = files.upload()

for filename in uploaded.keys():
  print(f'User uploaded file "{filename}"')
# Out:
#      <input type="file" id="files-0d6a79cf-9d63-4aee-96f5-50b04f4a1855" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d6a79cf-9d63-4aee-96f5-50b04f4a1855">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Install Pillow if you haven't already
# !pip install Pillow

# %%
from PIL import Image
import io

# Assuming you uploaded one image and its filename is available in the 'uploaded' dictionary
# Replace 'uploaded_image_filename.jpg' with the actual filename of your uploaded image
# You can get the filename from the output of the previous cell or by iterating through the 'uploaded' dictionary
filename = next(iter(uploaded)) # Gets the first filename from the uploaded dictionary

image_bytes = uploaded[filename]
image = Image.open(io.BytesIO(image_bytes))

# Display the image
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1132x900>
